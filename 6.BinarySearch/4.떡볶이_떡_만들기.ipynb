# %% [markdown]
# # 떡볶이 떡 만들기
#
# 떡의 길이가 일정하지 않다.
# 대신에 한 봉지 안에 들어가는 떡의 총 길이는 절단기로 잘라서 맞춰준다.
# 예를 들어 높이가 19, 14, 10, 17cm인 떡이 나란히 있고 절단기 높이를 15cm로 지정하여 자르면
# 떡의 높이는 15, 14, 10, 15cm가 될 것이다.
# 잘린 떡의 길이는 4, 0, 0, 2cm이다.
# 손님은 6cm만큼의 길이를 가져간다.
# 손님이 왔을 때 요청한 총 길이가 M일 때 적어도 M만큼의 떡을 얻기 위해 절단기에 설정할 수 있는 높이의 최댓값을 구하는 프로그램을 작성하시오.
# - - -
# ### 입력 조건
# - 첫째 줄에 떡의 개수 N과 요청한 떡의 길이 M이 주어진다. (1 <= N <= 1,000,000, 1 <= M <= 2,000,000,000)
# - 둘째 줄에는 떡의 개별 높이가 주어진다.
# 떡 높이의 총합은 항상 M 이상이므로, 손님은 필요한 양만큼 떡을 사갈 수 있다.
# 높이는 10억보다 작거나 같은 양의 정수 또는 0이다.
# - - -
# ### 출력 조건
# - 적어도 M만큼의 떡을 집에 가져가기 위해 절단기에 설정할 수 있는 높이의 최댓값을 출력한다.
# - - -
# ### 입력 예시
# 4 6
# 19 15 10 17
# - - -
# ### 출력 예시
# 15

# %%
# Input
n, m = map(int, input().split())
array = list(map(int, input().split()))
# Out:
# 4 6
# 19 15 10 17

# %%
# Input 2
n, m = 4, 6
array = [19, 15, 10, 17]

# %%
# Try
def slice(array, target):
    array.sort(reverse=True)
    cut = array[0] - 1
    sum = 0
    while cut > 0:
        for i in range(len(array)):
            if array[i] > cut:
                sum += array[i] - cut
        if sum >= target:
            return cut
        else:
            sum = 0
            cut -= 1
    return 0

print(slice(array, m))
# 순차 탐색으로 문제를 풀었기 때문에 막대한 양의 데이터가 들어오게 되면 O(N)으로
# 이진 탐색을 이용한 O(logN)보다 느리므로 시간 초과가 될 수 있다.
# Out:
# 32

# %%
# Solution
from IPython.core.debugger import set_trace
# 이진 탐색을 위한 시작점과 끝점 설정
start = 0
end = max(array)

# 이진 탐색 수행(반복적)
result = 0
while(start <= end):
    set_trace()
    total = 0
    mid = (start + end) // 2
    for x in array:
        # 잘랐을 때의 떡의 양 계산
        if x > mid:
            total += x - mid
    # 떡의 양이 부족한 경우 더 많이 자르기(왼쪽 부분 탐색)
    set_trace()
    if total < m:
        end = mid - 1
    # 떡의 양이 충분한 경우 덜 자르기(오른쪽 부분 탐색)
    else:
        result = mid # 최대한 덜 잘랐을 때가 정답이므로, 여기에서 result에 기록
        start = mid + 1
        
print(result)
# Out:
# > <ipython-input-23-357e07c5765c>(11)<module>()
#       9 while(start <= end):
#      10     set_trace()
# ---> 11     total = 0
#      12     mid = (start + end) // 2
#      13     for x in array:
#
# ipdb> c
# > <ipython-input-23-357e07c5765c>(19)<module>()
#      17     # 떡의 양이 부족한 경우 더 많이 자르기(왼쪽 부분 탐색)
#      18     set_trace()
# ---> 19     if total < m:
#      20         end = mid - 1
#      21     # 떡의 양이 충분한 경우 덜 자르기(오른쪽 부분 탐색)
#
# ipdb> mid
# 9
# ipdb> total
# 25
# ipdb> m
# 6
# ipdb> n
# > <ipython-input-23-357e07c5765c>(23)<module>()
#      21     # 떡의 양이 충분한 경우 덜 자르기(오른쪽 부분 탐색)
#      22     else:
# ---> 23         result = mid # 최대한 덜 잘랐을 때가 정답이므로, 여기에서 result에 기록
#      24         start = mid + 1
#      25
#
# ipdb> n
# > <ipython-input-23-357e07c5765c>(24)<module>()
#      22     else:
#      23         result = mid # 최대한 덜 잘랐을 때가 정답이므로, 여기에서 result에 기록
# ---> 24         start = mid + 1
#      25
#      26 print(result)
#
# ipdb> mid
# 9
# ipdb> s
# ...
