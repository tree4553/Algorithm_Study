# %% [markdown]
# # BFS
# 너비 우선 탐색(Breadth First Search)
# 큐 자료구조를 이용하며 동작 과정은 다음과 같다.
# > 1. 탐색 시작 노드를 큐에 삽입하고 방문 처리를 한다.
# 2. 큐에서 노드를 꺼내 해당 노드의 인접 노드 중에서 방문하지 않은 노드를 모두 큐에 삽입하고 방문 처리를 한다.
# 3. 2번의 과정을 더 이상 수행할 수 없을 때까지 반복한다.
#
# 가까운 노드부터 탐색을 진행하는 방식이다.

# %%
# 각 노드가 연결된 정보를 리스트 자료형으로 표현(2차원 리스트)
graph = [
    [],
    [2, 3, 8],
    [1, 7],
    [1, 4, 5],
    [3, 5],
    [3, 4],
    [7],
    [2, 6, 8],
    [1, 7]
]

# %% [markdown]
# ![](./DFS_Example_Graph.jpg)

# %%
from collections import deque

# BFS 메서드 정의
def bfs(graph, start, visited):
    # 큐(Queue) 구현을 위해 deque 라이브러리 사용
    queue = deque([start])
    # 현재 노드를 방문 처리
    visited[start] = True
    # 큐가 빌 때까지 반복
    while queue:
        # 큐에서 하나의 원소를 뽑아 출력
        v = queue.popleft()
        print(v, end = ' ')
        # 해당 원소와 연결된, 아직 방문하지 않은 원소들을 큐에 삽입
        for i in graph[v]:
            if not visited[i]:
                queue.append(i)
                visited[i] = True

# %%
# 각 노드가 방문된 정보를 리스트 자료형으로 표현(1차원 리스트)
visited = [False] * 9

# 정의된 DFS 함수 호출
bfs(graph, 1, visited)
# Out:
# 1 2 3 8 7 4 5 6

# %%
visited = [False] * 9
# %debug (bfs(graph, 1, visited))
# Out:
# NOTE: Enter 'c' at the ipdb>  prompt to continue execution.
# > <string>(1)<module>()
#
# ipdb> s
# --Call--
# > <ipython-input-4-61c0522edafd>(4)bfs()
#       2
#       3 # BFS 메서드 정의
# ----> 4 def bfs(graph, start, visited):
#       5     # 큐(Queue) 구현을 위해 deque 라이브러리 사용
#       6     queue = deque([start])
#
# ipdb> n
# > <ipython-input-4-61c0522edafd>(6)bfs()
#       4 def bfs(graph, start, visited):
#       5     # 큐(Queue) 구현을 위해 deque 라이브러리 사용
# ----> 6     queue = deque([start])
#       7     # 현재 노드를 방문 처리
#       8     visited[start] = True
#
# ipdb> n
# > <ipython-input-4-61c0522edafd>(8)bfs()
#       6     queue = deque([start])
#       7     # 현재 노드를 방문 처리
# ----> 8     visited[start] = True
#       9     # 큐가 빌 때까지 반복
#      10     while queue:
#
# ipdb> visited
# [False, False, False, False, False, False, False, False, False]
# ipdb> start
# 1
# ipdb> n
# > <ipython-input-4-61c0522edafd>(10)bfs()
#       8     visited[start] = True
#       9     # 큐가 빌 때까지 반복
# ---> 10     while queue:
#      11         # 큐에서 하나의 원소를 뽑아 출력
#      12         v = queue.popleft()
#
# ipdb> visited
# [False, True, False, False, False, False, False, False, False]
# ipdb> n
# > <ipython-input-4-61c0522edafd>(12)bfs()
#      10     while queue:
#      11         # 큐에서 하나의 원소를 뽑아 출력
# ---> 12         v = queue.popleft()
#      13         print(v, end = ' ')
#      14         # 해당 원소와 연결된, 아직 방문하지 않은 원소들을 큐에 삽입
#
# ipdb> n
# > <ipython-input-4-61c0522edafd>(13)bfs()
#      11         # 큐에서 하나의 원소를 뽑아 출력
#      12         v = queue.popleft()
# ---> 13         print(v, end = ' ')
#      14         # 해당 원소와 연결된, 아직 방문하지 않은 원소들을 큐에 삽입
#      15         for i in graph[v]:
#
# ipdb> v
# 1
# ipdb> n
# 1 > <ipython-input-4-61c0522edafd>(15)bfs()
#      13         print(v, end = ' ')
#      14         # 해당 원소와 연결된, 아직 방문하지 않은 원소들을 큐에 삽입
# ---> 15         for i in graph[v]:
#      16             if not visited[i]:
#      17                 queue.append(i)
#
# ipdb> n
# > <ipython-input-4-61c0522edafd>(16)bfs()
#      14         # 해당 원소와 연결된, 아직 방문하지 않은 원소들을 큐에 삽입
#      15         for i in graph[v]:
# ---> 16             if not visited[i]:
#      17                 queue.append(i)
#      18                 visited[i] = True
#
# ipdb> i
# 2
# ipdb> graph
# [[], [2, 3, 8], [1, 7], [1, 4, 5], [3, 5], [3, 4], [7], [2, 6, 8], [1, 7]]
# ipdb> visited[i]
# False
# ipdb> n
# > <ipython-input-4-61c0522edafd>(17)bfs()
#      14         # 해당 원소와 연결된, 아직 방문하지 않은 원소들을 큐에 삽입
#      15         for i in graph[v]:
#      16             if not visited[i]:
# ---> 17                 queue.append(i)
#      18                 visited[i] = True
#
# ipdb> n
# > <ipython-input-4-61c0522edafd>(18)bfs()
#      14         # 해당 원소와 연결된, 아직 방문하지 않은 원소들을 큐에 삽입
#      15         for i in graph[v]:
#      16             if not visited[i]:
#      17                 queue.append(i)
# ---> 18                 visited[i] = True
#
# ipdb> n
# > <ipython-input-4-61c0522edafd>(15)bfs()
#      13         print(v, end = ' ')
#      14         # 해당 원소와 연결된, 아직 방문하지 않은 원소들을 큐에 삽입
# ---> 15         for i in graph[v]:
#      16             if not visited[i]:
#      17                 queue.append(i)
# ipdb> visited
# [False, True, True, False, False, False, False, False, False]
# ipdb> n
# > <ipython-input-4-61c0522edafd>(16)bfs()
#      14         # 해당 원소와 연결된, 아직 방문하지 않은 원소들을 큐에 삽입
#      15         for i in graph[v]:
# ---> 16             if not visited[i]:
#      17                 queue.append(i)
#      18                 visited[i] = True
#
# ipdb> i
# 3
# ipdb> visited[i]
# False
# ipdb> n
# > <ipython-input-4-61c0522edafd>(17)bfs()
#      14         # 해당 원소와 연결된, 아직 방문하지 않은 원소들을 큐에 삽입
#      15         for i in graph[v]:
#      16             if not visited[i]:
# ---> 17                 queue.append(i)
#      18                 visited[i] = True
#
# ipdb> n
# > <ipython-input-4-61c0522edafd>(18)bfs()
#      14         # 해당 원소와 연결된, 아직 방문하지 않은 원소들을 큐에 삽입
#      15         for i in graph[v]:
#      16             if not visited[i]:
#      17                 queue.append(i)
# ---> 18                 visited[i] = True
#
# ipdb> n
# > <ipython-input-4-61c0522edafd>(15)bfs()
#      13         print(v, end = ' ')
#      14         # 해당 원소와 연결된, 아직 방문하지 않은 원소들을 큐에 삽입
# ---> 15         for i in graph[v]:
#      16             if not visited[i]:
#      17                 queue.append(i)
#
# ipdb> n
# > <ipython-input-4-61c0522edafd>(16)bfs()
#      14         # 해당 원소와 연결된, 아직 방문하지 않은 원소들을 큐에 삽입
#      15         for i in graph[v]:
# ---> 16             if not visited[i]:
#      17                 queue.append(i)
#      18                 visited[i] = True
#
# ipdb> graph[v]
# [2, 3, 8]
# ipdb> i
# 8
# ipdb> visited[i]
# False
# ipdb> n
# > <ipython-input-4-61c0522edafd>(17)bfs()
#      14         # 해당 원소와 연결된, 아직 방문하지 않은 원소들을 큐에 삽입
#      15         for i in graph[v]:
#      16             if not visited[i]:
# ---> 17                 queue.append(i)
#      18                 visited[i] = True
#
# ipdb> n
# > <ipython-input-4-61c0522edafd>(18)bfs()
#      14         # 해당 원소와 연결된, 아직 방문하지 않은 원소들을 큐에 삽입
#      15         for i in graph[v]:
#      16             if not visited[i]:
#      17                 queue.append(i)
# ---> 18                 visited[i] = True
#
# ipdb> n
# > <ipython-input-4-61c0522edafd>(15)bfs()
#      13         print(v, end = ' ')
#      14         # 해당 원소와 연결된, 아직 방문하지 않은 원소들을 큐에 삽입
# ---> 15         for i in graph[v]:
#      16             if not visited[i]:
#      17                 queue.append(i)
#
# ipdb> graph
# [[], [2, 3, 8], [1, 7], [1, 4, 5], [3, 5], [3, 4], [7], [2, 6, 8], [1, 7]]
# ipdb> graph[v]
# [2, 3, 8]
# ipdb> i
# 8
# ipdb> n
# > <ipython-input-4-61c0522edafd>(10)bfs()
#       8     visited[start] = True
#       9     # 큐가 빌 때까지 반복
# ---> 10     while queue:
#      11         # 큐에서 하나의 원소를 뽑아 출력
#      12         v = queue.popleft()
#
# ipdb> queue
# deque([2, 3, 8])
# ipdb> n
# > <ipython-input-4-61c0522edafd>(12)bfs()
#      10     while queue:
#      11         # 큐에서 하나의 원소를 뽑아 출력
# ---> 12         v = queue.popleft()
#      13         print(v, end = ' ')
#      14         # 해당 원소와 연결된, 아직 방문하지 않은 원소들을 큐에 삽입
#
# ipdb> n
# > <ipython-input-4-61c0522edafd>(13)bfs()
#      11         # 큐에서 하나의 원소를 뽑아 출력
#      12         v = queue.popleft()
# ---> 13         print(v, end = ' ')
#      14         # 해당 원소와 연결된, 아직 방문하지 않은 원소들을 큐에 삽입
#      15         for i in graph[v]:
# ipdb> v
# 2
# ipdb> n
# 2 > <ipython-input-4-61c0522edafd>(15)bfs()
#      13         print(v, end = ' ')
#      14         # 해당 원소와 연결된, 아직 방문하지 않은 원소들을 큐에 삽입
# ---> 15         for i in graph[v]:
#      16             if not visited[i]:
#      17                 queue.append(i)
#
# ipdb> n
# > <ipython-input-4-61c0522edafd>(16)bfs()
#      14         # 해당 원소와 연결된, 아직 방문하지 않은 원소들을 큐에 삽입
#      15         for i in graph[v]:
# ---> 16             if not visited[i]:
#      17                 queue.append(i)
#      18                 visited[i] = True
#
# ipdb> graph[v]
# [1, 7]
# ipdb> i
# 1
# ipdb> visited[i]
# True
# ipdb> n
# > <ipython-input-4-61c0522edafd>(15)bfs()
#      13         print(v, end = ' ')
#      14         # 해당 원소와 연결된, 아직 방문하지 않은 원소들을 큐에 삽입
# ---> 15         for i in graph[v]:
#      16             if not visited[i]:
#      17                 queue.append(i)
#
# ipdb> i
# 1
# ipdb> n
# > <ipython-input-4-61c0522edafd>(16)bfs()
#      14         # 해당 원소와 연결된, 아직 방문하지 않은 원소들을 큐에 삽입
#      15         for i in graph[v]:
# ---> 16             if not visited[i]:
#      17                 queue.append(i)
#      18                 visited[i] = True
#
# ipdb> visited[i]
# False
# ipdb> visited
# [False, True, True, True, False, False, False, False, True]
# ipdb> i
# 7
# ipdb> n
# > <ipython-input-4-61c0522edafd>(17)bfs()
#      14         # 해당 원소와 연결된, 아직 방문하지 않은 원소들을 큐에 삽입
#      15         for i in graph[v]:
#      16             if not visited[i]:
# ---> 17                 queue.append(i)
#      18                 visited[i] = True
#
# ipdb> n
# > <ipython-input-4-61c0522edafd>(18)bfs()
#      14         # 해당 원소와 연결된, 아직 방문하지 않은 원소들을 큐에 삽입
#      15         for i in graph[v]:
#      16             if not visited[i]:
#      17                 queue.append(i)
# ---> 18                 visited[i] = True
#
# ipdb> n
# > <ipython-input-4-61c0522edafd>(15)bfs()
#      13         print(v, end = ' ')
#      14         # 해당 원소와 연결된, 아직 방문하지 않은 원소들을 큐에 삽입
# ---> 15         for i in graph[v]:
#      16             if not visited[i]:
#      17                 queue.append(i)
#
# ipdb> n
# > <ipython-input-4-61c0522edafd>(10)bfs()
#       8     visited[start] = True
#       9     # 큐가 빌 때까지 반복
# ---> 10     while queue:
#      11         # 큐에서 하나의 원소를 뽑아 출력
#      12         v = queue.popleft()
#
# ipdb> queue
# deque([3, 8, 7])
# ipdb> n
# > <ipython-input-4-61c0522edafd>(12)bfs()
#      10     while queue:
#      11         # 큐에서 하나의 원소를 뽑아 출력
# ---> 12         v = queue.popleft()
#      13         print(v, end = ' ')
#      14         # 해당 원소와 연결된, 아직 방문하지 않은 원소들을 큐에 삽입
#
# ipdb> n
# > <ipython-input-4-61c0522edafd>(13)bfs()
#      11         # 큐에서 하나의 원소를 뽑아 출력
#      12         v = queue.popleft()
# ---> 13         print(v, end = ' ')
#      14         # 해당 원소와 연결된, 아직 방문하지 않은 원소들을 큐에 삽입
#      15         for i in graph[v]:
#
# ipdb> v
# 3
# ipdb> c
# 3 8 7 4 5 6
